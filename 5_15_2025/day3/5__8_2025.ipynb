# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as mpl

# %%
df = pd.DataFrame({
    "strings":['Adam','Mike'],
    'ints':[1,3],
    'floats':[1.123,1000.23]
})

df.style \
.format(precision=3,thousands='.',decimal=',') \
.format_index(str.upper,axis=1) \
.relabel_index(['row 1','row 2'], axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d57ae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d57ae_level0_col0" class="col_heading level0 col0" >STRINGS</th>
#       <th id="T_d57ae_level0_col1" class="col_heading level0 col1" >INTS</th>
#       <th id="T_d57ae_level0_col2" class="col_heading level0 col2" >FLOATS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d57ae_level0_row0" class="row_heading level0 row0" >row 1</th>
#       <td id="T_d57ae_row0_col0" class="data row0 col0" >Adam</td>
#       <td id="T_d57ae_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_d57ae_row0_col2" class="data row0 col2" >1,123</td>
#     </tr>
#     <tr>
#       <th id="T_d57ae_level0_row1" class="row_heading level0 row1" >row 2</th>
#       <td id="T_d57ae_row1_col0" class="data row1 col0" >Mike</td>
#       <td id="T_d57ae_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_d57ae_row1_col2" class="data row1 col2" >1.000,230</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = pd.DataFrame(np.random.randn(5,5))
df.style \
    .hide(subset=[0,2,4], axis=0) \
    .hide(subset=[0,2,4], axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_87861">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87861_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_87861_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87861_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87861_row1_col1" class="data row1 col1" >-1.885103</td>
#       <td id="T_87861_row1_col3" class="data row1 col3" >-1.666682</td>
#     </tr>
#     <tr>
#       <th id="T_87861_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_87861_row3_col1" class="data row3 col1" >2.408410</td>
#       <td id="T_87861_row3_col3" class="data row3 col3" >0.331886</td>
#     </tr>
#   </tbody>
# </table>

# %%
s = pd.Series(np.random.randn(5), index=['a','b','c','d','e'])

# %%
s
# Out:
# a   -0.028589
# b   -1.308156
# c   -1.226710
# d   -0.595181
# e    0.587768
# dtype: float64

# %%
pd.Series([1,2],dtype=np.int64).reindex([0,1,2])
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
pd.Series([True,False],dtype=np.bool_).reindex([0,1,2])
# Out:
# 0     True
# 1    False
# 2      NaN
# dtype: object

# %%
sensor_data = pd.Series([True,False])
